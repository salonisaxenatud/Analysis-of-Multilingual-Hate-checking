# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, det_curve
import numpy as np
import matplotlib.pyplot as plt

# %%
cultural = pd.read_csv('cultural_hd.csv')

# %%
noncultural = pd.read_csv('noncultural_hd.csv')

# %%
toxic = pd.read_csv('toxic.csv')
nontoxic = pd.read_csv('nontoxic.csv')
hs = pd.read_csv('def_hate_speech.csv')

# %%
no_exps = ['नहीं', 'No', 'Nie']
yes_exps = ['Tak', 'Yes', 'हाँ']
cultural['gt_num'] = [0 if i in no_exps else 1 for i in cultural['ground_truth']]
cultural['pred_num'] = [0 if i in no_exps else 1 for i in cultural['prediction']]
noncultural['gt_num'] = [0 if i in no_exps else 1 for i in noncultural['ground_truth']]
noncultural['pred_num'] = [0 if i in no_exps else 1 for i in noncultural['prediction']]

# %%
toxic['gt_num'] = [0 if i in no_exps else 1 for i in toxic['ground_truth']]
toxic['pred_num'] = [0 if i in no_exps else 1 for i in toxic['prediction']]
nontoxic['gt_num'] = [0 if i in no_exps else 1 for i in nontoxic['ground_truth']]
nontoxic['pred_num'] = [0 if i in no_exps else 1 for i in nontoxic['prediction']]
hs['gt_num'] = [0 if i in no_exps else 1 for i in hs['ground_truth']]
hs['pred_num'] = [0 if i in no_exps else 1 for i in hs['prediction']]

# %%
cultural_pl = cultural[cultural['language'] == 'polish']
cultural_hn = cultural[cultural['language'] == 'hindi']
cultural_en = cultural[cultural['language'] == 'english']

# %%
noncultural_pl = noncultural[noncultural['language'] == 'polish']
noncultural_hn = noncultural[noncultural['language'] == 'hindi']
noncultural_en = noncultural[noncultural['language'] == 'english']

# %%
toxic_pl = toxic[toxic['language'] == 'polish']
toxic_hn = toxic[toxic['language'] == 'hindi']
toxic_en = toxic[toxic['language'] == 'english']

# %%
hs_pl = hs[hs['language'] == 'polish']
hs_hn = hs[hs['language'] == 'hindi']
hs_en = hs[hs['language'] == 'english']

# %%
nontoxic_pl = nontoxic[nontoxic['language'] == 'polish']
nontoxic_hn = nontoxic[nontoxic['language'] == 'hindi']
nontoxic_en = nontoxic[nontoxic['language'] == 'english']

# %%
cultural_acc = accuracy_score(cultural['gt_num'], cultural['pred_num'])
cultural_prec = precision_score(cultural['gt_num'], cultural['pred_num'])
cultural_rec = recall_score(cultural['gt_num'], cultural['pred_num'])
cultural_fpr = 1 - recall_score(cultural['gt_num'], cultural['pred_num'], pos_label = 0)
cultural_fnr = 1 - recall_score(cultural['gt_num'], cultural['pred_num'])

# %%
noncultural_acc = accuracy_score(noncultural['gt_num'], noncultural['pred_num'])
noncultural_prec = precision_score(noncultural['gt_num'], noncultural['pred_num'])
noncultural_rec = recall_score(noncultural['gt_num'], noncultural['pred_num'])
noncultural_fpr = 1 - recall_score(noncultural['gt_num'], noncultural['pred_num'], pos_label = 0)
noncultural_fnr = 1 - recall_score(noncultural['gt_num'], noncultural['pred_num'])

# %%
toxic_acc = accuracy_score(toxic['gt_num'], toxic['pred_num'])
toxic_prec = precision_score(toxic['gt_num'], toxic['pred_num'])
toxic_rec = recall_score(toxic['gt_num'], toxic['pred_num'])
toxic_fpr = 1 - recall_score(toxic['gt_num'], toxic['pred_num'], pos_label = 0)
toxic_fnr = 1 - recall_score(toxic['gt_num'], toxic['pred_num'])

# %%
nontoxic_acc = accuracy_score(nontoxic['gt_num'], nontoxic['pred_num'])
nontoxic_prec = precision_score(nontoxic['gt_num'], nontoxic['pred_num'])
nontoxic_rec = recall_score(nontoxic['gt_num'], nontoxic['pred_num'])
nontoxic_fpr = 1 - recall_score(nontoxic['gt_num'], nontoxic['pred_num'], pos_label = 0)
nontoxic_fnr = 1 - recall_score(nontoxic['gt_num'], nontoxic['pred_num'])

# %%
hs_acc = accuracy_score(hs['gt_num'], hs['pred_num'])
hs_prec = precision_score(hs['gt_num'], hs['pred_num'])
hs_rec = recall_score(hs['gt_num'], hs['pred_num'])
hs_fpr = 1 - recall_score(hs['gt_num'], hs['pred_num'], pos_label = 0)
hs_fnr = 1 - recall_score(hs['gt_num'], hs['pred_num'])

# %%
cultural_pl_acc = accuracy_score(cultural_pl['gt_num'], cultural_pl['pred_num'])
cultural_pl_prec = precision_score(cultural_pl['gt_num'], cultural_pl['pred_num'])
cultural_pl_rec = recall_score(cultural_pl['gt_num'], cultural_pl['pred_num'])
cultural_pl_fpr = 1 - recall_score(cultural_pl['gt_num'], cultural_pl['pred_num'], pos_label = 0)
cultural_pl_fnr = 1 - recall_score(cultural_pl['gt_num'], cultural_pl['pred_num'])

# %%
noncultural_pl_acc = accuracy_score(noncultural_pl['gt_num'], noncultural_pl['pred_num'])
noncultural_pl_prec = precision_score(noncultural_pl['gt_num'], noncultural_pl['pred_num'])
noncultural_pl_rec = recall_score(noncultural_pl['gt_num'], noncultural_pl['pred_num'])
noncultural_pl_fpr = 1 - recall_score(noncultural_pl['gt_num'], noncultural_pl['pred_num'], pos_label = 0)
noncultural_pl_fnr = 1 - recall_score(noncultural_pl['gt_num'], noncultural_pl['pred_num'])

# %%
toxic_pl_acc = accuracy_score(toxic_pl['gt_num'], toxic_pl['pred_num'])
toxic_pl_prec = precision_score(toxic_pl['gt_num'], toxic_pl['pred_num'])
toxic_pl_rec = recall_score(toxic_pl['gt_num'], toxic_pl['pred_num'])
toxic_pl_fpr = 1 - recall_score(toxic_pl['gt_num'], toxic_pl['pred_num'], pos_label = 0)
toxic_pl_fnr = 1 - recall_score(toxic_pl['gt_num'], toxic_pl['pred_num'])

# %%
nontoxic_pl_acc = accuracy_score(nontoxic_pl['gt_num'], nontoxic_pl['pred_num'])
nontoxic_pl_prec = precision_score(nontoxic_pl['gt_num'], nontoxic_pl['pred_num'])
nontoxic_pl_rec = recall_score(nontoxic_pl['gt_num'], nontoxic_pl['pred_num'])
nontoxic_pl_fpr = 1 - recall_score(nontoxic_pl['gt_num'], nontoxic_pl['pred_num'], pos_label = 0)
nontoxic_pl_fnr = 1 - recall_score(nontoxic_pl['gt_num'], nontoxic_pl['pred_num'])

# %%
hs_pl_acc = accuracy_score(hs_pl['gt_num'], hs_pl['pred_num'])
hs_pl_prec = precision_score(hs_pl['gt_num'], hs_pl['pred_num'])
hs_pl_rec = recall_score(hs_pl['gt_num'], hs_pl['pred_num'])
hs_pl_fpr = 1 - recall_score(hs_pl['gt_num'], hs_pl['pred_num'], pos_label = 0)
hs_pl_fnr = 1 - recall_score(hs_pl['gt_num'], hs_pl['pred_num'])

# %%
cultural_en_acc = accuracy_score(cultural_en['gt_num'], cultural_en['pred_num'])
cultural_en_prec = precision_score(cultural_en['gt_num'], cultural_en['pred_num'])
cultural_en_rec = recall_score(cultural_en['gt_num'], cultural_en['pred_num'])
cultural_en_fpr = 1 - recall_score(cultural_en['gt_num'], cultural_en['pred_num'], pos_label = 0)
cultural_en_fnr = 1 - recall_score(cultural_en['gt_num'], cultural_en['pred_num'])

# %%
noncultural_en_acc = accuracy_score(noncultural_en['gt_num'], noncultural_en['pred_num'])
noncultural_en_prec = precision_score(noncultural_en['gt_num'], noncultural_en['pred_num'])
noncultural_en_rec = recall_score(noncultural_en['gt_num'], noncultural_en['pred_num'])
noncultural_en_fpr = 1 - recall_score(noncultural_en['gt_num'], noncultural_en['pred_num'], pos_label = 0)
noncultural_en_fnr = 1 - recall_score(noncultural_en['gt_num'], noncultural_en['pred_num'])

# %%
toxic_en_acc = accuracy_score(toxic_en['gt_num'], toxic_en['pred_num'])
toxic_en_prec = precision_score(toxic_en['gt_num'], toxic_en['pred_num'])
toxic_en_rec = recall_score(toxic_en['gt_num'], toxic_en['pred_num'])
toxic_en_fpr = 1 - recall_score(toxic_en['gt_num'], toxic_en['pred_num'], pos_label = 0)
toxic_en_fnr = 1 - recall_score(toxic_en['gt_num'], toxic_en['pred_num'])

# %%
nontoxic_en_acc = accuracy_score(nontoxic_en['gt_num'], nontoxic_en['pred_num'])
nontoxic_en_prec = precision_score(nontoxic_en['gt_num'], nontoxic_en['pred_num'])
nontoxic_en_rec = recall_score(nontoxic_en['gt_num'], nontoxic_en['pred_num'])
nontoxic_en_fpr = 1 - recall_score(nontoxic_en['gt_num'], nontoxic_en['pred_num'], pos_label = 0)
nontoxic_en_fnr = 1 - recall_score(nontoxic_en['gt_num'], nontoxic_en['pred_num'])

# %%
hs_en_acc = accuracy_score(hs_en['gt_num'], hs_en['pred_num'])
hs_en_prec = precision_score(hs_en['gt_num'], hs_en['pred_num'])
hs_en_rec = recall_score(hs_en['gt_num'], hs_en['pred_num'])
hs_en_fpr = 1 - recall_score(hs_en['gt_num'], hs_en['pred_num'], pos_label = 0)
hs_en_fnr = 1 - recall_score(hs_en['gt_num'], hs_en['pred_num'])

# %%
cultural_hn_acc = accuracy_score(cultural_hn['gt_num'], cultural_hn['pred_num'])
cultural_hn_prec = precision_score(cultural_hn['gt_num'], cultural_hn['pred_num'])
cultural_hn_rec = recall_score(cultural_hn['gt_num'], cultural_hn['pred_num'])
cultural_hn_fpr = 1 - recall_score(cultural_hn['gt_num'], cultural_hn['pred_num'], pos_label = 0)
cultural_hn_fnr = 1 - recall_score(cultural_hn['gt_num'], cultural_hn['pred_num'])

# %%
noncultural_hn_acc = accuracy_score(noncultural_hn['gt_num'], noncultural_hn['pred_num'])
noncultural_hn_prec = precision_score(noncultural_hn['gt_num'], noncultural_hn['pred_num'])
noncultural_hn_rec = recall_score(noncultural_hn['gt_num'], noncultural_hn['pred_num'])
noncultural_hn_fpr = 1 - recall_score(noncultural_hn['gt_num'], noncultural_hn['pred_num'], pos_label = 0)
noncultural_hn_fnr = 1 - recall_score(noncultural_hn['gt_num'], noncultural_hn['pred_num'])

# %%
toxic_hn_acc = accuracy_score(toxic_hn['gt_num'], toxic_hn['pred_num'])
toxic_hn_prec = precision_score(toxic_hn['gt_num'], toxic_hn['pred_num'])
toxic_hn_rec = recall_score(toxic_hn['gt_num'], toxic_hn['pred_num'])
toxic_hn_fpr = 1 - recall_score(toxic_hn['gt_num'], toxic_hn['pred_num'], pos_label = 0)
toxic_hn_fnr = 1 - recall_score(toxic_hn['gt_num'], toxic_hn['pred_num'])

# %%
nontoxic_hn_acc = accuracy_score(nontoxic_hn['gt_num'], nontoxic_hn['pred_num'])
nontoxic_hn_prec = precision_score(nontoxic_hn['gt_num'], nontoxic_hn['pred_num'])
nontoxic_hn_rec = recall_score(nontoxic_hn['gt_num'], nontoxic_hn['pred_num'])
nontoxic_hn_fpr = 1 - recall_score(nontoxic_hn['gt_num'], nontoxic_hn['pred_num'], pos_label = 0)
nontoxic_hn_fnr = 1 - recall_score(nontoxic_hn['gt_num'], nontoxic_hn['pred_num'])

# %%
hs_hn_acc = accuracy_score(hs_hn['gt_num'], hs_hn['pred_num'])
hs_hn_prec = precision_score(hs_hn['gt_num'], hs_hn['pred_num'])
hs_hn_rec = recall_score(hs_hn['gt_num'], hs_hn['pred_num'])
hs_hn_fpr = 1 - recall_score(hs_hn['gt_num'], hs_hn['pred_num'], pos_label = 0)
hs_hn_fnr = 1 - recall_score(hs_hn['gt_num'], hs_hn['pred_num'])

# %%
cultural_accs = [cultural_acc, cultural_pl_acc, cultural_hn_acc, cultural_en_acc]
cultural_recs = [cultural_rec, cultural_pl_rec, cultural_hn_rec, cultural_en_rec]
cultural_precs = [cultural_prec, cultural_pl_prec, cultural_hn_prec, cultural_en_prec]
cultural_fprs = [cultural_fpr, cultural_pl_fpr, cultural_hn_fpr, cultural_en_fpr]
cultural_fnrs = [cultural_fnr, cultural_pl_fnr, cultural_hn_fnr, cultural_en_fnr]

# %%
noncultural_accs = [noncultural_acc, noncultural_pl_acc, noncultural_hn_acc, noncultural_en_acc]
noncultural_recs = [noncultural_rec, noncultural_pl_rec, noncultural_hn_rec, noncultural_en_rec]
noncultural_precs = [noncultural_prec, noncultural_pl_prec, noncultural_hn_prec, noncultural_en_prec]
noncultural_fprs = [noncultural_fpr, noncultural_pl_fpr, noncultural_hn_fpr, noncultural_en_fpr]
noncultural_fnrs = [noncultural_fnr, noncultural_pl_fnr, noncultural_hn_fnr, noncultural_en_fnr]

# %%
toxic_accs = [toxic_acc, toxic_pl_acc, toxic_hn_acc, toxic_en_acc]
toxic_recs = [toxic_rec, toxic_pl_rec, toxic_hn_rec, toxic_en_rec]
toxic_precs = [toxic_prec, toxic_pl_prec, toxic_hn_prec, toxic_en_prec]
toxic_fprs = [toxic_fpr, toxic_pl_fpr, toxic_hn_fpr, toxic_en_fpr]
toxic_fnrs = [toxic_fnr, toxic_pl_fnr, toxic_hn_fnr, toxic_en_fnr]

# %%
nontoxic_accs = [nontoxic_acc, nontoxic_pl_acc, nontoxic_hn_acc, nontoxic_en_acc]
nontoxic_recs = [nontoxic_rec, nontoxic_pl_rec, nontoxic_hn_rec, nontoxic_en_rec]
nontoxic_precs = [nontoxic_prec, nontoxic_pl_prec, nontoxic_hn_prec, nontoxic_en_prec]
nontoxic_fprs = [nontoxic_fpr, nontoxic_pl_fpr, nontoxic_hn_fpr, nontoxic_en_fpr]
nontoxic_fnrs = [nontoxic_fnr, nontoxic_pl_fnr, nontoxic_hn_fnr, nontoxic_en_fnr]

# %%
hs_accs = [hs_acc, hs_pl_acc, hs_hn_acc, hs_en_acc]
hs_recs = [hs_rec, hs_pl_rec, hs_hn_rec, hs_en_rec]
hs_precs = [hs_prec, hs_pl_prec, hs_hn_prec, hs_en_prec]
hs_fprs = [hs_fpr, hs_pl_fpr, hs_hn_fpr, hs_en_fpr]
hs_fnrs = [hs_fnr, hs_pl_fnr, hs_hn_fnr, hs_en_fnr]

# %%
cult_dict = {
  'Accuracy': cultural_accs,
  'Precision': cultural_precs,
  'Recall': cultural_recs,
  'False Positive Rate': cultural_fprs,
  'False Negative Rate': cultural_fnrs
}

# %%
noncult_dict = {
  'Accuracy': noncultural_accs,
  'Precision': noncultural_precs,
  'Recall': noncultural_recs,
  'False Positive Rate': noncultural_fprs,
  'False Negative Rate': noncultural_fnrs
}

# %%
toxic_dict = {
  'Accuracy': toxic_accs,
  'Precision': toxic_precs,
  'Recall': toxic_recs,
  'False Positive Rate': toxic_fprs,
  'False Negative Rate': toxic_fnrs
}

# %%
nontoxic_dict = {
  'Accuracy': nontoxic_accs,
  'Precision': nontoxic_precs,
  'Recall': nontoxic_recs,
  'False Positive Rate': nontoxic_fprs,
  'False Negative Rate': nontoxic_fnrs
}

# %%
hs_dict = {
  'Accuracy': hs_accs,
  'Precision': hs_precs,
  'Recall': hs_recs,
  'False Positive Rate': hs_fprs,
  'False Negative Rate': hs_fnrs
}

# %%
species = ['All', 'Polish', 'English', 'Hindi']

# %%
x = np.arange(len(species))  # the label locations
width = 0.15  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained', figsize=(15, 7))

for attribute, measurement in cult_dict.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    multiplier += 1


group_center = x + width * 4 / 2
ax.set_xticks(group_center)
ax.set_xticklabels(species)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Score')
ax.set_xlabel('Language')
ax.set_title('Evaluation scores by language: cultural')
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)

plt.show()

# %%
x = np.arange(len(species))  # the label locations
width = 0.15  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained', figsize=(15, 7))

for attribute, measurement in noncult_dict.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    multiplier += 1


group_center = x + width * 4 / 2
ax.set_xticks(group_center)
ax.set_xticklabels(species)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Score')
ax.set_xlabel('Language')
ax.set_title('Evaluation scores by language: non-cultural')
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)

plt.show()

# %%
x = np.arange(len(species))  # the label locations
width = 0.15  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained', figsize=(15, 7))

for attribute, measurement in toxic_dict.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    multiplier += 1


group_center = x + width * 4 / 2
ax.set_xticks(group_center)
ax.set_xticklabels(species)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Score')
ax.set_xlabel('Language')
ax.set_title('Evaluation scores by language: toxic (non-hate speech) examples')
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)

plt.show()

# %%
x = np.arange(len(species))  # the label locations
width = 0.15  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained', figsize=(15, 7))

for attribute, measurement in nontoxic_dict.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    multiplier += 1


group_center = x + width * 4 / 2
ax.set_xticks(group_center)
ax.set_xticklabels(species)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Score')
ax.set_xlabel('Language')
ax.set_title('Evaluation scores by language: non-toxic examples')
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)

plt.show()

# %%
x = np.arange(len(species))  # the label locations
width = 0.15  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained', figsize=(15, 7))

for attribute, measurement in nontoxic_dict.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    multiplier += 1


group_center = x + width * 4 / 2
ax.set_xticks(group_center)
ax.set_xticklabels(species)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Score')
ax.set_xlabel('Language')
ax.set_title('Evaluation scores by language: hate-speech examples')
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)

plt.show()

# %%
noncultural_list = [noncultural_acc, noncultural_prec, noncultural_rec, noncultural_fpr, noncultural_fnr]
noncultural_pl_list = [noncultural_pl_acc, noncultural_pl_prec, noncultural_pl_rec, noncultural_pl_fpr, noncultural_pl_fnr]
noncultural_hn_list = [noncultural_hn_acc, noncultural_hn_prec, noncultural_hn_rec, noncultural_hn_fpr, noncultural_hn_fnr]
noncultural_en_list = [noncultural_en_acc, noncultural_en_prec, noncultural_en_rec, noncultural_en_fpr, noncultural_en_fnr]

# %%
cultural_list = [cultural_acc, cultural_prec, cultural_rec, cultural_fpr, cultural_fnr]
cultural_pl_list = [cultural_pl_acc, cultural_pl_prec, cultural_pl_rec, cultural_pl_fpr, cultural_pl_fnr]
cultural_hn_list = [cultural_hn_acc, cultural_hn_prec, cultural_hn_rec, cultural_hn_fpr, cultural_hn_fnr]
cultural_en_list = [cultural_en_acc, cultural_en_prec, cultural_en_rec, cultural_en_fpr, cultural_en_fnr]

# %%
toxic_list = [toxic_acc, toxic_prec, toxic_rec, toxic_fpr, toxic_fnr]
toxic_pl_list = [toxic_pl_acc, toxic_pl_prec, toxic_pl_rec, toxic_pl_fpr, toxic_pl_fnr]
toxic_hn_list = [toxic_hn_acc, toxic_hn_prec, toxic_hn_rec, toxic_hn_fpr, toxic_hn_fnr]
toxic_en_list = [toxic_en_acc, toxic_en_prec, toxic_en_rec, toxic_en_fpr, toxic_en_fnr]

# %%
nontoxic_list = [nontoxic_acc, nontoxic_prec, nontoxic_rec, nontoxic_fpr, nontoxic_fnr]
nontoxic_pl_list = [nontoxic_pl_acc, nontoxic_pl_prec, nontoxic_pl_rec, nontoxic_pl_fpr, nontoxic_pl_fnr]
nontoxic_hn_list = [nontoxic_hn_acc, nontoxic_hn_prec, nontoxic_hn_rec, nontoxic_hn_fpr, nontoxic_hn_fnr]
nontoxic_en_list = [nontoxic_en_acc, nontoxic_en_prec, nontoxic_en_rec, nontoxic_en_fpr, nontoxic_en_fnr]

# %%
hs_list = [hs_acc, hs_prec, hs_rec, hs_fpr, hs_fnr]
hs_pl_list = [hs_pl_acc, hs_pl_prec, hs_pl_rec, hs_pl_fpr, hs_pl_fnr]
hs_hn_list = [hs_hn_acc, hs_hn_prec, hs_hn_rec, hs_hn_fpr, hs_hn_fnr]
hs_en_list = [hs_en_acc, hs_en_prec, hs_en_rec, hs_en_fpr, hs_en_fnr]

# %%
noncult_dict_2 = {
  'All': noncultural_list,
  'Polish': noncultural_pl_list,
  'English': noncultural_en_list,
  'Hindi': noncultural_hn_list
}

# %%
cult_dict_2 = {
  'All': cultural_list,
  'Polish': cultural_pl_list,
  'English': cultural_en_list,
  'Hindi': cultural_hn_list
}

# %%
toxic_dict_2 = {
  'All': toxic_list,
  'Polish': toxic_pl_list,
  'English': toxic_en_list,
  'Hindi': toxic_hn_list
}

# %%
nontoxic_dict_2 = {
  'All': nontoxic_list,
  'Polish': nontoxic_pl_list,
  'English': nontoxic_en_list,
  'Hindi': nontoxic_hn_list
}

# %%
hs_dict_2 = {
  'All': hs_list,
  'Polish': hs_pl_list,
  'English': hs_en_list,
  'Hindi': hs_hn_list
}

# %%
species_2 = ['Accuracy', 'Precision', 'Recall', 'False Positive Rate', 'False Negative Rate']

# %%
x = np.arange(len(species_2))  # the label locations
width = 0.15  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained', figsize=(15, 7))

for attribute, measurement in noncult_dict_2.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    multiplier += 1


group_center = x + width * 4 / 2
ax.set_xticks(group_center)
ax.set_xticklabels(species_2)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Score')
ax.set_xlabel('Measure')
ax.set_title('Evaluation scores by language: non-cultural')
ax.set_xticks(x + width, species_2)
ax.legend(loc='upper right', ncols=3)

plt.show()

# %%
x = np.arange(len(species_2))  # the label locations
width = 0.15  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained', figsize=(15, 7))

for attribute, measurement in cult_dict_2.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    multiplier += 1


group_center = x + width * 4 / 2
ax.set_xticks(group_center)
ax.set_xticklabels(species_2)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Score')
ax.set_xlabel('Measure')
ax.set_title('Evaluation scores by language: cultural')
ax.set_xticks(x + width, species_2)
ax.legend(loc='upper right', ncols=3)

plt.show()

# %%
x = np.arange(len(species_2))  # the label locations
width = 0.15  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained', figsize=(15, 7))

for attribute, measurement in toxic_dict_2.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    multiplier += 1


group_center = x + width * 4 / 2
ax.set_xticks(group_center)
ax.set_xticklabels(species_2)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Score')
ax.set_xlabel('Measure')
ax.set_title('Evaluation scores by language: toxic (non-hate speech) examples')
ax.set_xticks(x + width, species_2)
ax.legend(loc='upper right', ncols=3)

plt.show()

# %%
x = np.arange(len(species_2))  # the label locations
width = 0.15  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained', figsize=(15, 7))

for attribute, measurement in nontoxic_dict_2.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    multiplier += 1


group_center = x + width * 4 / 2
ax.set_xticks(group_center)
ax.set_xticklabels(species_2)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Score')
ax.set_xlabel('Measure')
ax.set_title('Evaluation scores by language: non-toxic examples')
ax.set_xticks(x + width, species_2)
ax.legend(loc='upper right', ncols=3)

plt.show()

# %%
x = np.arange(len(species_2))  # the label locations
width = 0.15  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained', figsize=(15, 7))

for attribute, measurement in hs_dict_2.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    multiplier += 1


group_center = x + width * 4 / 2
ax.set_xticks(group_center)
ax.set_xticklabels(species_2)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Score')
ax.set_xlabel('Measure')
ax.set_title('Evaluation scores by language: hate-speech examples')
ax.set_xticks(x + width, species_2)
ax.legend(loc='upper right', ncols=3)

plt.show()
